# %%
# Importing Necessary Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading from directory
df= pd.read_csv("cars.csv")

# %%
df.head(7)
# Out:
#    Unnamed: 0  Unit                vin    price    miles  year Unnamed: 6  \
# 0           1     1  19UDE2F3XGA002005  16997.0  25499.0  2016        NaN
# 1           2     1  19UUB1F35FA009543  21491.0  33352.0  2015        NaN
# 2           3     1  19UUB2F75FA000172  24499.0  22888.0  2015        NaN
# 3           4     1  1C4BJWDG7HL502000  33635.0  17956.0  2017        NaN
# 4           5     1  1C4NJPCB5ED547385  13878.0  71061.0  2014        NaN
# 5           6     1  1C4NJRFB9GD586040  12998.0  65101.0  2016        NaN
# 6           7     1  1C4RJFAG1EC205173  17998.0  80411.0  2014        NaN
#
#             model vehicle_type body_type  ...  \
# 0             ILX          Car     Sedan  ...
# 1             TLX          Car     Sedan  ...
# 2             TLX          Van     Sedan  ...
# 3        Wrangler          SUV       SUV  ...
# 4         Patriot          SUV       SUV  ...
# 5         Patriot          SUV       SUV  ...
# 6  Grand Cherokee          SUV       SUV  ...
#
#                                 color         zip state       city  \
# 0                                 NaN       28273    NC  Charlotte
# 1            Graphite Luster Metallic       28227    NC  Charlotte
# 2            Graphite Luster Metallic       28269    NC  Charlotte
# 3                     Firecracker Red       28227    NC  Charlotte
# 4                 True Blue Pearlcoat  28273-6935    NC  Charlotte
# 5  Granite Crystal Metallic Clearcoat       28227    NC  Charlotte
# 6   Deep Cherry Red Crystal Pearlcoat       28227    NC  Charlotte
#
#   seller_type is_certified    dom dom_180     msrp                 seller_name
# 0      dealer          NaN   60.0    60.0  16997.0              hendrick honda
# 1      dealer          NaN   90.0     3.0  21491.0                hendrick bmw
# 2      dealer          1.0   83.0    82.0  24499.0              audi northlake
# 3      dealer          NaN  154.0    27.0  33635.0              hendrick acura
# 4      dealer          NaN  110.0    49.0  13878.0  hendrickcars.com charlotte
# 5      dealer          NaN   93.0    64.0  12998.0            jaguar charlotte
# 6      dealer          NaN   46.0    11.0  17998.0              hendrick acura
#
# [7 rows x 23 columns]

# %%
df.shape
# Out:
# (5044, 23)

# %%
df.mode().T
# Out:
#                            0                  1                  2     \
# Unnamed: 0                    1                  2                  3
# Unit                        1.0                NaN                NaN
# vin           19UDE2F35GA013042  19UDE2F3XGA002005  19UDE2F73GA000518
# price                   14981.0                NaN                NaN
# miles                       8.0                NaN                NaN
# year                     2015.0                NaN                NaN
# Unnamed: 6            Chevrolet                NaN                NaN
# model                  3 Series                NaN                NaN
# vehicle_type                Car                NaN                NaN
# body_type                   SUV                NaN                NaN
# fuel_type      Regular Unleaded                NaN                NaN
# engine         2.4L L4 DOHC 16V                NaN                NaN
# transmission          Automatic                NaN                NaN
# color                     Black                NaN                NaN
# zip                       28211                NaN                NaN
# state                        NC                NaN                NaN
# city                  Charlotte                NaN                NaN
# seller_type              dealer                NaN                NaN
# is_certified                1.0                NaN                NaN
# dom                         2.0                NaN                NaN
# dom_180                     2.0                NaN                NaN
# msrp                    14981.0                NaN                NaN
# seller_name    sonic automotive                NaN                NaN
#
#                            3                  4                  5     \
# Unnamed: 0                    4                  5                  6
# Unit                        NaN                NaN                NaN
# vin           19UDE2F74GA007445  19UDE2F79HA001349  19UDE2F83GA004111
# price                       NaN                NaN                NaN
# miles                       NaN                NaN                NaN
# year                        NaN                NaN                NaN
# Unnamed: 6                  NaN                NaN                NaN
# model                       NaN                NaN                NaN
# vehicle_type                NaN                NaN                NaN
# body_type                   NaN                NaN                NaN
# fuel_type                   NaN                NaN                NaN
# engine                      NaN                NaN                NaN
# transmission                NaN                NaN                NaN
# color                       NaN                NaN                NaN
# zip                         NaN                NaN                NaN
# state                       NaN                NaN                NaN
# city                        NaN                NaN                NaN
# seller_type                 NaN                NaN                NaN
# is_certified                NaN                NaN                NaN
# dom                         NaN                NaN                NaN
# dom_180                     NaN                NaN                NaN
# msrp                        NaN                NaN                NaN
# seller_name                 NaN                NaN                NaN
#
#                            6                  7                  8     \
# Unnamed: 0                    7                  8                  9
# Unit                        NaN                NaN                NaN
# vin           19UDE2F84GA009706  19UUA568X3A050977  19UUA66215A030217
# price                       NaN                NaN                NaN
# miles                       NaN                NaN                NaN
# year                        NaN                NaN                NaN
# Unnamed: 6                  NaN                NaN                NaN
# model                       NaN                NaN                NaN
# vehicle_type                NaN                NaN                NaN
# body_type                   NaN                NaN                NaN
# fuel_type                   NaN                NaN                NaN
# engine                      NaN                NaN                NaN
# transmission                NaN                NaN                NaN
# color                       NaN                NaN                NaN
# zip                         NaN                NaN                NaN
# state                       NaN                NaN                NaN
# city                        NaN                NaN                NaN
# seller_type                 NaN                NaN                NaN
# is_certified                NaN                NaN                NaN
# dom                         NaN                NaN                NaN
# dom_180                     NaN                NaN                NaN
# msrp                        NaN                NaN                NaN
# seller_name                 NaN                NaN                NaN
#
#                            9     ...               5034               5035  \
# Unnamed: 0                   10  ...               5035               5036
# Unit                        NaN  ...                NaN                NaN
# vin           19UUA66235A071755  ...  ZACCJADT6GPC82962  ZACCJADTXGPC62469
# price                       NaN  ...                NaN                NaN
# miles                       NaN  ...                NaN                NaN
# year                        NaN  ...                NaN                NaN
# Unnamed: 6                  NaN  ...                NaN                NaN
# model                       NaN  ...                NaN                NaN
# vehicle_type                NaN  ...                NaN                NaN
# body_type                   NaN  ...                NaN                NaN
# fuel_type                   NaN  ...                NaN                NaN
# engine                      NaN  ...                NaN                NaN
# transmission                NaN  ...                NaN                NaN
# color                       NaN  ...                NaN                NaN
# zip                         NaN  ...                NaN                NaN
# state                       NaN  ...                NaN                NaN
# city                        NaN  ...                NaN                NaN
# seller_type                 NaN  ...                NaN                NaN
# is_certified                NaN  ...                NaN                NaN
# dom                         NaN  ...                NaN                NaN
# dom_180                     NaN  ...                NaN                NaN
# msrp                        NaN  ...                NaN                NaN
# seller_name                 NaN  ...                NaN                NaN
#
#                            5036               5037               5038  \
# Unnamed: 0                 5037               5038               5039
# Unit                        NaN                NaN                NaN
# vin           ZACCJBBT4GPD15451  ZACCJBBT7GPD59184  ZACCJBCTXFPB92722
# price                       NaN                NaN                NaN
# miles                       NaN                NaN                NaN
# year                        NaN                NaN                NaN
# Unnamed: 6                  NaN                NaN                NaN
# model                       NaN                NaN                NaN
# vehicle_type                NaN                NaN                NaN
# body_type                   NaN                NaN                NaN
# fuel_type                   NaN                NaN                NaN
# engine                      NaN                NaN                NaN
# transmission                NaN                NaN                NaN
# color                       NaN                NaN                NaN
# zip                         NaN                NaN                NaN
# state                       NaN                NaN                NaN
# city                        NaN                NaN                NaN
# seller_type                 NaN                NaN                NaN
# is_certified                NaN                NaN                NaN
# dom                         NaN                NaN                NaN
# dom_180                     NaN                NaN                NaN
# msrp                        NaN                NaN                NaN
# seller_name                 NaN                NaN                NaN
#
#                            5039               5040               5041  \
# Unnamed: 0                 5040               5041               5042
# Unit                        NaN                NaN                NaN
# vin           ZACCJBDT1FPB27501  ZAM56RPA7G1166331  ZAM56RRA2E1076420
# price                       NaN                NaN                NaN
# miles                       NaN                NaN                NaN
# year                        NaN                NaN                NaN
# Unnamed: 6                  NaN                NaN                NaN
# model                       NaN                NaN                NaN
# vehicle_type                NaN                NaN                NaN
# body_type                   NaN                NaN                NaN
# fuel_type                   NaN                NaN                NaN
# engine                      NaN                NaN                NaN
# transmission                NaN                NaN                NaN
# color                       NaN                NaN                NaN
# zip                         NaN                NaN                NaN
# state                       NaN                NaN                NaN
# city                        NaN                NaN                NaN
# seller_type                 NaN                NaN                NaN
# is_certified                NaN                NaN                NaN
# dom                         NaN                NaN                NaN
# dom_180                     NaN                NaN                NaN
# msrp                        NaN                NaN                NaN
# seller_name                 NaN                NaN                NaN
#
#                            5042               5043
# Unnamed: 0                 5043               5044
# Unit                        NaN                NaN
# vin           ZAM57RTA3F1150225  ZFBCFADH3GZ037974
# price                       NaN                NaN
# miles                       NaN                NaN
# year                        NaN                NaN
# Unnamed: 6                  NaN                NaN
# model                       NaN                NaN
# vehicle_type                NaN                NaN
# body_type                   NaN                NaN
# fuel_type                   NaN                NaN
# engine                      NaN                NaN
# transmission                NaN                NaN
# color                       NaN                NaN
# zip                         NaN                NaN
# state                       NaN                NaN
# city                        NaN                NaN
# seller_type                 NaN                NaN
# is_certified                NaN                NaN
# dom                         NaN                NaN
# dom_180                     NaN                NaN
# msrp                        NaN                NaN
# seller_name                 NaN                NaN
#
# [23 rows x 5044 columns]

# %%
# Droping uncessary columns
df.drop(['Unnamed: 0'], inplace=True, axis=1)

# %%
# Renaming Columns
df.rename(columns={'Unnamed: 6':'Manufaturer'}, inplace=True)

# %%
# Missing value percentage per column
missing= df.isnull().sum()/df.shape[0]*100
missing
# Out:
# Unit             0.000000
# vin              0.000000
# price            8.386201
# miles            3.984933
# year             0.000000
# Manufaturer     22.482157
# model            0.059477
# vehicle_type     0.158604
# body_type        3.053132
# fuel_type        4.103886
# engine           6.978588
# transmission     9.595559
# color           38.560666
# zip              0.000000
# state            0.000000
# city             0.000000
# seller_type      0.000000
# is_certified    82.513878
# dom              0.019826
# dom_180          0.019826
# msrp            14.234734
# seller_name      0.000000
# dtype: float64

# %%
# Total missing value percentage
cell = np.product(df.shape)
total_missing = df.isnull().sum().sum()
(total_missing/cell) * 100
# Out:
# 8.825066685891429

# %%
import missingno as msno
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Testing

# %%
NA_val = df_cleaned.isna().sum()
def na_filter(na, threshold = .4): #only select variables that passees the threshold
    col_pass = []
    for i in na.keys():
        if na[i]/df_cleaned.shape[0]<threshold:
            col_pass.append(i)
            return col_pass#df_cleaned 
            df_cleaned[na_filter(NA_val)]
df_cleaned.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 NA_val = df_cleaned.isna().sum()
#       2 def na_filter(na, threshold = .4): #only select variables that passees the threshold
#       3     col_pass = []
#
# NameError: name 'df_cleaned' is not defined

# %%
condition =.3
def clean_df():
    df_cleaned = df.copy()
    df_cleaned['condition'] = df_cleaned.apply(lambda row: clean_condition(row), axis=1)
    return df_cleaned s# Get df with reclassfied 'condition' column
df_cleaned = clean_df()
print(df_cleaned.condition.unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 6>()
#       4     df_cleaned['condition'] = df_cleaned.apply(lambda row: clean_condition(row), axis=1)
#       5     return df_cleaned# Get df with reclassfied 'condition' column
# ----> 6 df_cleaned = clean_df()
#       7 print(df_cleaned.condition.unique())
#
# Input In [8], in clean_df()
#       2 def clean_df():
#       3     df_cleaned = df.copy()
# ----> 4     df_cleaned['condition'] = df_cleaned.apply(lambda row: clean_condition(row), axis=1)
#       5     return df_cleaned
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:851, in FrameApply.apply_standard(self)
#     850 def apply_standard(self):
# --> 851     results, res_index = self.apply_series_generator()
#     853     # wrap results
#     854     return self.wrap_results(results, res_index)
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:867, in FrameApply.apply_series_generator(self)
#     864 with option_context("mode.chained_assignment", None):
#     865     for i, v in enumerate(series_gen):
#     866         # ignore SettingWithCopy here in case the user mutates
# --> 867         results[i] = self.f(v)
#     868         if isinstance(results[i], ABCSeries):
#     869             # If we have a view on v, we need to make a copy because
#     870             #  series_generator will swap out the underlying data
#     871             results[i] = results[i].copy(deep=False)
#
# Input In [8], in clean_df.<locals>.<lambda>(row)
#       2 def clean_df():
#       3     df_cleaned = df.copy()
# ----> 4     df_cleaned['condition'] = df_cleaned.apply(lambda row: clean_condition(row), axis=1)
#       5     return df_cleaned
#
# NameError: name 'clean_condition' is not defined

# %%
for column in df:
    def filter(na, threshold=.4):
        col=[]
        for i in na.keys():
            if na[i]/df_cleaned.shape[0]<threshold:
                col.append(i)
        return col
        #print(df[column])

# %%
col
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 col
#
# NameError: name 'col' is not defined

# %%
msno.matrix(df_cleaned)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## End of Testing

# %%
# droping columns with more empty values
df.drop(['color','is_certified'], inplace= True, axis=1)

# %%
df.columns
# Out:
# Index(['Unit', 'vin', 'price', 'miles', 'year', 'Manufaturer', 'model',
#        'vehicle_type', 'body_type', 'fuel_type', 'engine', 'transmission',
#        'zip', 'state', 'city', 'seller_type', 'dom', 'dom_180', 'msrp',
#        'seller_name'],
#       dtype='object')

# %%
# Data Visualization and EDA
"""  """

# %%
# transmission
"counting types of entries in transmission column"
plt.figure(figsize=(18,6))
sns.countplot(x =df['transmission'], data= df)
plt.legend(df['transmission'])
plt.show()

# %%
# Encoding transmission coulumn
df['transmission']=df['transmission'].apply(lambda x:'Manual' if x=='Manual' else ('Automated Manual' if x=='Automated Manual' else ('Automatic' if x=='Automatic' else 'others')))

# %%
# Encoding result of transmission
plt.figure(figsize=(10,6))
sns.countplot(x =df['transmission'], data = df)
plt.show()

# %%
# Vehicle Type
"counting types of entries in vehicle column"
plt.figure(figsize=(16,6))
sns.countplot(x =df['vehicle_type'], data= df)
plt.show()

# %%
# Applying encoding on vehicle_type
df['vehicle_type']=df['vehicle_type'].apply(lambda x:'Truck' if x=='Truck' else ('Car' if x=='Car' else ('SUV' if x=='SUV' else  ('Van' if x=='Van' else ('others')))))

# %%
# Encoding result of Vehicle_Type
plt.figure(figsize=(12,6))
sns.countplot(x =df['vehicle_type'],palette='Paired',data= df)
plt.show()

# %%
# Body Type
"counting types of entries in body_type"
plt.figure(figsize=(10,6))
sns.countplot(y =df['body_type'], data= df)
plt.legend(df['body_type'])
plt.show()

# %%
# zip code
"counting types of entries in zip code"plt.figure(figsize=(10,6))
sns.countplot(y =df['zip'], palette='rocket', data= df)
plt.show()

# %%
# Manufaturer
"counting types of entries in zip code"
plt.figure(figsize=(12,10))
sns.countplot(y =df['Manufaturer'], palette='cool',data= df)
plt.show()

# %%
# fuel_type
"counting types of entries in zip code"
plt.figure(figsize=(10,6))
sns.countplot(y =df['fuel_type'], palette='deep', data= df)
plt.show()

# %%
# year wise price of Vehicles according to their "vehicle_type"
plt.figure(figsize=(20, 10))
sns.barplot("year","price", hue="vehicle_type", ci=None, estimator=np.sum, data=df, palette="muted")
# Out:
# c:\users\hasan\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='price'>

# %%
# year wise price of Vehicles according to their "body_type"
plt.figure(figsize=(16,10))
sns.barplot("year", "price",  hue="body_type", ci=None, estimator=np.sum, data=df, palette='muted')
plt.show()
# Out:
# c:\users\hasan\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#####

# %%
sales_region_tier = df.groupby(["vehicle_type"])['year'].sum()
sales_region_tier

# %%
explode = (0.1,0)  
fig1, ax1 = plt.subplots(figsize=(12,7))
ax1.pie(df['vehicle_type'].value_counts(), labels=['Car','SUV','Truck','Van','others'],autopct='%1.1f%%', shadow=True, startangle=90) # 
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.legend()
plt.show()

# %%
dom_180 = df.dom_180
plt.figure(figsize=(10, 12))

sns.countplot(x =df['body_type'], hue= 'body_type', data = df) # df.set_index(['year', 'month'])
plt.show()
#x = df([dom_180])

# %%
plt.figure(figsize=(12,10))
sns.distplot(df['price'])
plt.show()
# Out:
# c:\users\hasan\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12,10))
sns.relplot(x="miles", y="price", data=df, kind="scatter");
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.relplot(x="body_type", y="price", hue="body_type",data=df);
plt.show()

# %%
plt.figure(figsize=(10,12))
sns.catplot(x="body_type", y="price", kind='swarm',data=df);
plt.show()
# Out:
# c:\users\hasan\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 89.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\hasan\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 89.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\hasan\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 84.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\hasan\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 82.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\hasan\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 89.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\hasan\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 77.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\hasan\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 80.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(10,10))
sns.catplot(x="body_type", y="year",kind="box",data=df);
plt.show()

# %%
plt.figure(figsize=(10, 12))
#ax = sns.barplot("body_type", "year",ci = None, estimator = np.sum, data = df)
#ax.set_title("Global Sales By Genre")
sns.countplot(df['body_type'], hue=df['year'])
# Out:
# F:\installed\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='body_type', ylabel='count'>

# %%
#stacked bar chart
sales_region_tier.plot(kind="barh",stacked=True,figsize=(12,12))
plt.xlabel("Sales")
plt.ylabel("Region/Tier")
plt.title("Total sales of 2015 and 2016 with respect to Region and Tiers")
plt.show()

# %%
df=df.sort_values(by=['year'],ascending=False)
plt.figure(figsize=(25,15))
sns.barplot(x=df.zip, y=df.year)
plt.xticks(rotation= 90)
plt.xlabel('transmission')
plt.ylabel('vehicle_type')
plt.show()

# %%
df1 = df.groupby([df["zip"],df["city"]]).sum()

# %%
df1
# Out:
#                       Unit       price       miles     year      dom  dom_180  \
# zip        city
# 28201      Charlotte    51    926278.0   2971005.0   102661   3751.0   1281.0
# 28205      Charlotte   147  10885645.0    574904.0   295193  25075.0  21531.0
# 28206      Charlotte    23    400797.0   2674382.0    46258   3129.0   2877.0
# 28206-2756 Charlotte     3     41875.0    298217.0     6035   1723.0   1467.0
# 28208      Charlotte    29    254829.0   2661030.0    58300   2244.0   1427.0
# 28210-6642 Charlotte     2     14400.0    360812.0     4010     55.0     55.0
# 28211      Charlotte  1645  37284212.0  79371720.0  3312647  79497.0  52357.0
# 28212      Charlotte   573  11111344.0  30678852.0  1153814  46033.0  31841.0
# 28213      Charlotte   380   6109998.0  23028738.0   765044  33943.0  23879.0
# 28213-7920 Charlotte    21    494037.0   1346243.0    42292   1454.0   1041.0
# 28214      Charlotte    53    953995.0   2665577.0   106820   4919.0   4308.0
# 28216      Charlotte     1         0.0    835187.0     2007     37.0     37.0
# 28217      Charlotte    19    465916.0   1143950.0    38247   2162.0   1114.0
# 28226      Charlotte     1      7500.0    136000.0     2010     21.0      0.0
# 28227      Charlotte   828  17949239.0  39112405.0  1667816  55255.0  36063.0
# 28262      Charlotte     6    135300.0    252364.0    12089    379.0    213.0
# 28269      Charlotte   288   6424647.0  14060426.0   580093  20288.0  13053.0
# 28270      Charlotte     1      3400.0    199082.0     2006    137.0    137.0
# 28273      Charlotte   727  15191059.0  35991716.0  1464325  57429.0  35813.0
# 28273-6935 Charlotte   217   4374503.0  11527785.0   437006  12667.0   8268.0
# 48813      Charlotte    29    429535.0   2208464.0    58353   2684.0    924.0
#
#                             msrp
# zip        city
# 28201      Charlotte    827938.0
# 28205      Charlotte     41528.0
# 28206      Charlotte    383898.0
# 28206-2756 Charlotte     41875.0
# 28208      Charlotte    254829.0
# 28210-6642 Charlotte     14400.0
# 28211      Charlotte  37653560.0
# 28212      Charlotte  10391223.0
# 28213      Charlotte   6335304.0
# 28213-7920 Charlotte    494037.0
# 28214      Charlotte   1025175.0
# 28216      Charlotte         0.0
# 28217      Charlotte    465916.0
# 28226      Charlotte      7500.0
# 28227      Charlotte  14820098.0
# 28262      Charlotte    135300.0
# 28269      Charlotte   6366192.0
# 28270      Charlotte      3400.0
# 28273      Charlotte  14801767.0
# 28273-6935 Charlotte   4374503.0
# 48813      Charlotte    447535.0

# %%
# Analytics

# %%
" Q1 how many vehicles are there which are having dom_180(are in stockyard from last 180 days)?"
" Q2 Arrange the ascending and descending order of the above list?"
" Q3 How much capital is involved in question 1st?"
" Q4 which are the top ten costly model are in data?"
" Q5 which seller sells most of vehicles?"
" Q6 which seller sells more vehicles from dom_180 list?"
" Q7 which sellers are least selling?"
" Q8 Most and Least Selling Vehicles in year 2011,12,13,...17?"
" Q9 Quick Selling cars company"
" Q10 Slow selling Cars company"

# %%
" Q1 how many vehicles are there which are having dom_180(are in stockyard from last 180 days)?"
sns.distplot(df['dom_180'])    
dom_180 = df[df['dom_180']>=180]
print(len(dom_180))                                            
dom_180.head()
# Out:
# 194
# c:\users\hasan\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
#       Unit                vin    price   miles  year    Manufaturer     model  \
# 1708     1  55SWF4JB6JU249307  35981.0  4708.0  2018  Mercedes-Benz   C-Class
# 4253     1  WBXHU7C33J5H44076  39986.0    12.0  2018            BMW        X1
# 3818     1  WBXHT3C38J5K21189      NaN     NaN  2018            BMW        X1
# 218      1  WBA8A3C5XJA357784  26981.0  9670.0  2018            NaN  3 Series
# 1574     1  WBA8E5G50JNU45651  43174.0    12.0  2018            BMW  3 Series
#
#      vehicle_type body_type         fuel_type engine transmission    zip  \
# 1708          Car     Sedan          Gasoline   M274    Automatic  28211
# 4253          SUV       SUV          Gasoline    NaN       others  28211
# 3818          SUV       SUV  Premium Unleaded    NaN    Automatic  28227
# 218           Car     Sedan          Gasoline    NaN       others  28211
# 1574          Car     Sedan          Gasoline    NaN       others  28211
#
#      state       city seller_type    dom  dom_180     msrp       seller_name
# 1708    NC  Charlotte      dealer  265.0    265.0  35981.0  sonic automotive
# 4253    NC  Charlotte      dealer  181.0    181.0  39986.0  sonic automotive
# 3818    NC  Charlotte      dealer  221.0    221.0  41086.0     hendrick mini
# 218     NC  Charlotte      dealer  201.0    193.0  26981.0  sonic automotive
# 1574    NC  Charlotte      dealer  238.0    202.0  43174.0  sonic automotive

# %%
" Q2 Arrange the ascending and descending order of the above list?"
dom180_asc = dom_180.sort_values(by=['dom_180'], ascending = True)
sns.distplot(dom180_asc['dom_180']);
#(dom180_asc['dom_180']).describe()
dom180_des = dom_180.sort_values(by=['dom_180'], ascending = False)
# Out:
# c:\users\hasan\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
" Q3 How much capital is involved in question 1st?"
sns.distplot(dom_180['price']);
# (dom_180['price']).describe()
(dom_180['price']).sum()
# Out:
# c:\users\hasan\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 4328515.0

# %%
" Q4 which are the top ten costly model are in data?"
costly = (df.sort_values(by=['price'],ascending = False)).head(10)
sns.distplot(costly['price']);
costly['price'].describe()
# Out:
# c:\users\hasan\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# count        10.000000
# mean     872934.700000
# std       88473.622191
# min      749584.000000
# 25%      799916.000000
# 50%      866087.000000
# 75%      937153.500000
# max      999584.000000
# Name: price, dtype: float64

# %%
" Q5 which seller sells most of vehicles?"
most_sell = df['seller_name'].value_counts()
print("\nseller with most selling\n", most_sell.head(1))
# Out:
# seller with most selling
#  sonic automotive    1645
# Name: seller_name, dtype: int64

# %%
" Q6 which seller sells more vehicles from dom_180 list?"
sell180 = dom_180['seller_name'].value_counts()
print("\n highest sale from dom_180\n", sell180.head(1))
# Out:
#  highest sale from dom_180
#  pty motors    29
# Name: seller_name, dtype: int64

# %%
" Q7 which sellers are least selling?"
least_sell = most_sell.sort_values(ascending = True)
print("\n sellers with least sell\n",least_sell.head(12))
# Out:
#  sellers with least sell
#  prime auto sales              1
# east coast motorsports        1
# scott jaguar                  1
# latorre automotive group      1
# duckworth automotive          1
# south charlotte pre-owned     1
# carz 4 less                   1
# joe's trucks center           1
# kd automotive                 1
# c.l. badgett auto showcase    1
# furrst class cars             1
# little rock auto sales        1
# Name: seller_name, dtype: int64

# %%
" Q8 Most and Least Selling Vehicles in year 2011,12,13,...17?"
cars_2011 = (df[df["year"]==2011])
cars_2011 = (cars_2011["vehicle_type"]).value_counts()
print("\nMost Sales in 2011:\n", cars_2011.head(1))
print("\nLeast Sales in 2011:\n", cars_2011.tail(1))

cars_2012 = (df[df['year']==2012])
cars_2012 = (cars_2012['vehicle_type']).value_counts()
print("\nMost Sales in 2012:\n", cars_2011.head(1))
print("\nLeast Sales in 2012:\n", cars_2011.tail(1))

cars_2013 = (df[df['year']==2013])
cars_2013 = (cars_2013['vehicle_type']).value_counts()
print("\nMost Sales in 2013:\n", cars_2011.head(1))
print("\nLeast Sales in 2013:\n", cars_2011.tail(1))

cars_2014 = (df[df['year']==2014])
cars_2014 = (cars_2014['vehicle_type']).value_counts()
print("\nMost Sales in 2014:\n", cars_2011.head(1))
print("\nLeast Sales in 2014:\n", cars_2011.tail(1))

cars_2015 = (df[df['year']==2015])
cars_2015 = (cars_2015['vehicle_type']).value_counts()
print("\nMost Sales in 2015:\n", cars_2011.head(1))
print("\nLeast Sales in 2015:\n", cars_2011.tail(1))

cars_2016 = (df[df['year']==2016])
cars_2016 = (cars_2016['vehicle_type']).value_counts()
print("\nMost Sales in 2016:\n", cars_2011.head(1))
print("\nLeast Sales in 2016:\n", cars_2011.tail(1))

cars_2017 = (df[df['year']==2017])
cars_2017 = (cars_2017['vehicle_type']).value_counts()
print("\nMost Sales in 2017:\n", cars_2011.head(1))
print("\nLeast Sales in 2017:\n", cars_2011.tail(1))
# Out:
# Most Sales in 2011:
#  Car    101
# Name: vehicle_type, dtype: int64
#
# Least Sales in 2011:
#  Van    4
# Name: vehicle_type, dtype: int64
#
# Most Sales in 2012:
#  Car    101
# Name: vehicle_type, dtype: int64
#
# Least Sales in 2012:
#  Van    4
# Name: vehicle_type, dtype: int64
#
# Most Sales in 2013:
#  Car    101
# Name: vehicle_type, dtype: int64
#
# Least Sales in 2013:
#  Van    4
# Name: vehicle_type, dtype: int64
#
# Most Sales in 2014:
#  Car    101
# Name: vehicle_type, dtype: int64
#
# Least Sales in 2014:
#  Van    4
# Name: vehicle_type, dtype: int64
#
# Most Sales in 2015:
#  Car    101
# Name: vehicle_type, dtype: int64
#
# Least Sales in 2015:
#  Van    4
# Name: vehicle_type, dtype: int64
#
# Most Sales in 2016:
#  Car    101
# Name: vehicle_type, dtype: int64
#
# Least Sales in 2016:
#  Van    4
# Name: vehicle_type, dtype: int64
#
# Most Sales in 2017:
#  Car    101
# Name: vehicle_type, dtype: int64
#
# Least Sales in 2017:
#  Van    4
# Name: vehicle_type, dtype: int64

# %%
year = cars_2011 + cars_2012 + cars_2013 + cars_2014 + cars_2015 + cars_2016 + cars_2017

# %%
# Encoding

# %%
# Encoding transmission coulumn
df['transmission']=df['transmission'].apply(lambda x:'2' if x=='Manual' else ('1' if x=='Automated Manual' else ('3' if x=='Automatic' else '0')))

# %%
# Applying encoding on vehicle_type
df['vehicle_type']=df['vehicle_type'].apply(lambda x:'2' if x=='Truck' else ('4' if x=='Car' else ('3' if x=='SUV' else  ('1' if x=='Van' else ('0')))))

# %%
# Applying encoding on vehicle_type
df['vehicle_type']=df['vehicle_type'].apply(lambda x:'2' if x=='Truck' else ('4' if x=='Car' else ('3' if x=='SUV' else  ('1' if x=='Van' else ('0')))))

# %%
plt.figure(figsize=(14,12))
sns.countplot(df['seller_type'])
plt.show()
# Out:
# c:\users\hasan\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# encoding state
df['state']=df['state'].apply(lambda x:'0' if x=='NC' else('1' if x=='MI' else 'others'))

# %%
# encoding city
df['city']=df['city'].apply(lambda x:'0' if x=='Charlotte' else('1' if x=='others' else 'others'))

# %%
# encoding body_state
df['body_type']=df['body_type'].map({"Sedan":0, "SUV":1, "Pickup":2, "Coupe":3, "Hatchback":4, "Convertible":5, "Wagon":6, "van":7, "Chassis":8})
df["body_type"].value_counts()
# Out:
# 1.0    1835
# 0.0    1806
# 2.0     514
# 4.0     254
# 3.0     249
# 5.0     119
# 6.0     108
# 8.0       3
# Name: body_type, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Maufaturer']=le.fit_transform(df['Manufaturer'])

# %%
df.dtypes
# Out:
# Unit              int64
# vin              object
# price           float64
# miles           float64
# year              int64
# Manufaturer      object
# model            object
# vehicle_type     object
# body_type       float64
# fuel_type        object
# engine           object
# transmission     object
# zip              object
# state            object
# city             object
# seller_type      object
# dom             float64
# dom_180         float64
# msrp            float64
# seller_name      object
# Maufaturer        int32
# dtype: object

# %%
# converting object data type into float

# %%
df['vehicle_type']=df.vehicle_type.astype(str).astype(float)

# %%
df['body_type']=df.body_type.astype(str).astype(float)

# %%
df['transmission']=df.transmission.astype(str).astype(float)

# %%
df['state']=df.state.astype(str).astype(float)

# %%
df['city']=df.state.astype(str).astype(float)

# %%
# Correllogram
# Import Dataset
#df = pd.read_csv("cars.csv")

# Plot
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns, cmap='RdYlGn', center=0, annot=True)

# Decorations
plt.title('Correlogram of cars', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.subplots(figsize=(15,8))
sns.countplot('year',data=df,palette='RdYlGn_r',edgecolor=sns.color_palette("husl", 10))
plt.xticks(rotation=90)
plt.title('Activities by Year',fontsize=20)
plt.xlabel('Year',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.show()
# Out:
# F:\installed\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# The plot shows as the number of sales has been increased in recent years

# %%
pd.crosstab(df.year, df.vehicle_type).plot(kind='area',figsize=(15,6))
plt.title('Activities by Region each year', fontsize=18)
plt.xlabel('year', fontsize= 15)
plt.ylabel('Number', fontsize= 15)
plt.show()

# %%
# Number of Sales increase mostly in "SUV" and "Car" segment

# %%
# subplots for each of the category of Outlet_Size
plt.figure(figsize=(12,10))
sns.relplot(x="body_type", y="price",hue='year',col='year',data=df);
plt.show()

# %%
from wordcloud import WordCloud
from scipy import signal
cities = df.vehicle_type.dropna(False)
plt.subplots(figsize=(10,10))
wc = WordCloud(background_color='black',width=400, height=400).generate(' '.join(cities))
plt.axis('off')
plt.imshow(wc)
plt.show()

# %%
plt.bar(df.city, df.vehile_type, label='Bars1', color ='r') # Function to plot
  
# Function to give x and y labels 
plt.xlabel("Country")
plt.ylabel("Inflation Rate%")

# Function to give heading of the chart
plt.title("Bar Graph")

# Function to show the chart
plt.show()

# %%
# Function to plot the graph
plt.pie(df['vehicle_type'],labels=df['vehicle_type'],autopct='%.2f%%')
plt.axis('equal')
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18180/3628133004.py in <module>
#       1 # Function to plot the graph
# ----> 2 plt.pie(df['vehicle_type'],labels=df['vehicle_type'],autopct='%.2f%%')
#       3 plt.axis('equal')
#       4 plt.axis('equal')
#       5 plt.show()
#
# NameError: name 'plt' is not defined
